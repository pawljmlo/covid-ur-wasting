# %% [markdown]
# <a href="https://colab.research.google.com/github/pawljmlo/covid-ur-wasting/blob/main/%20plot-charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## import data

# %%
path_overlapping = "/content/drive/MyDrive/projekty/review-ai-covid-ur/data/covid-data-extracted-overlapping-edited.csv"

# %%
df = pd.read_csv(path_overlapping).drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#            Reference ID ID in the review  ...              X-ray    Other.1
# 0        chen2020review               15  ...  0,540816326530612  #DZIEL/0!
# 1       islam2020review               91  ...  0,535714285714286  #DZIEL/0!
# 2  nguyen2020artificial               46  ...            #VALUE!  #DZIEL/0!
# 3  shoeibi2020automated               77  ...            #VALUE!  #DZIEL/0!
# 4     ulhaq2020computer           64->63  ...            #VALUE!  #DZIEL/0!
#
# [5 rows x 58 columns]

# %% [markdown]
# ## select proper data and edit it

# %%
df.columns
# Out:
# Index(['Reference ID', 'ID in the review', 'Primary study Bibtex ID', 'Num',
#        'Per one', 'New', 'Reference', 'Medium', 'What', 'Link',
#        'Was ver. reported?', 'Date reported', 'Versions', 'Ver. Used', 'Month',
#        'Day', 'Published?', 'Pub-link', 'Journal', 'Conference', 'Other',
#        'Av-Month', 'Av-Day', 'Av-Year', 'Retracted',
#        'How many datasets were used?', 'Total CTs', 'C-19 CTs', 'Total X-Rays',
#        'C-19 X-rays', 'Total other', 'C-19 other',
#        'Viral pneumonia (non-COVID)', 'Bacterial pneumonia',
#        'Unknown pneumonia', 'Unclear', 'Asymptomatic controls',
#        'Control patients', 'C-19 patients', 'Total patients',
#        'Architecture name', 'Architecture modification', 'Accuracy', 'AUC',
#        'F1', 'Precision', 'NPV', 'Sensitivity', 'Specifity',
#        'Balanced Accuracy', 'Other metrics', 'Post processing',
#        'Sens. and Spec.', 'Both scans', 'Sens., Spec., Both', 'CT', 'X-ray',
#        'Other.1'],
# ...

# %%
interesting_columns = ['Primary study Bibtex ID', 'Reference ID', 'Month', 'Day',
                       'Total CTs', 'C-19 CTs', 'Total X-Rays', 'C-19 X-rays', 'Total other', 'C-19 other', 
                       'Control patients', 'C-19 patients', 'Total patients', 
                       'Accuracy', 'AUC', 'F1', 'Precision', 'NPV', 'Sensitivity', 'Specifity', 'Balanced Accuracy', 'Other metrics']

# %%
df = df[interesting_columns]
df.head()
# Out:
#    Primary study Bibtex ID  ... Other metrics
# 0  abbas2020classification  ...            NR
# 1  abbas2020classification  ...            NR
# 2  abbas2020classification  ...            NR
# 3  abbas2020classification  ...            NR
# 4  abbas2020classification  ...            NR
#
# [5 rows x 22 columns]

# %%
df['Year'] = '2020'
df['Day'] = df['Day'].replace('NR', 1) # approximation

# %%
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])
df = df.drop(['Year', 'Month', 'Day'], axis=1)

# %%
df = df.replace('NR', np.nan)

# %%
id_multiple_models = []

for id, group in df.groupby('Primary study Bibtex ID'):

  if not (group.shape[0] == len(group['Reference ID'].unique())):
    id_multiple_models.append(id)

# %%
df = df[~df['Primary study Bibtex ID'].isin(id_multiple_models)]
df.head()
# Out:
#    Primary study Bibtex ID          Reference ID  ... Other metrics       Date
# 0  abbas2020classification        chen2020review  ...           NaN 2020-03-26
# 1  abbas2020classification       islam2020review  ...           NaN 2020-03-26
# 2  abbas2020classification  nguyen2020artificial  ...           NaN 2020-03-26
# 3  abbas2020classification  shoeibi2020automated  ...           NaN 2020-03-26
# 4  abbas2020classification     ulhaq2020computer  ...           NaN 2020-03-26
#
# [5 rows x 21 columns]

# %%
df[['Other metrics - value', 'Other metrics - name']] = df['Other metrics'].str.split(", ", expand=True).drop(2, axis=1)
df = df.drop('Other metrics', axis=1)
df.head()
# Out:
#    Primary study Bibtex ID  ... Other metrics - name
# 0  abbas2020classification  ...                  NaN
# 1  abbas2020classification  ...                  NaN
# 2  abbas2020classification  ...                  NaN
# 3  abbas2020classification  ...                  NaN
# 4  abbas2020classification  ...                  NaN
#
# [5 rows x 22 columns]

# %%
df['C INDEX'] = df[df['Other metrics - name'] == 'C INDEX']['Other metrics - value']
df = df.drop(['Other metrics - value', 'Other metrics - name'], axis=1)

# %%
columns_to_num = ['Total CTs', 'C-19 CTs', 'Total X-Rays', 'C-19 X-rays', 'Total other', 'C-19 other', 
                  'Control patients', 'C-19 patients', 'Total patients', 
                  'Accuracy', 'AUC', 'F1', 'Precision', 'NPV', 'Sensitivity', 'Specifity', 'Balanced Accuracy', 'C INDEX']

columns_metrics = ['Accuracy', 'AUC', 'F1', 'Precision', 'NPV', 'Sensitivity', 'Specifity', 'Balanced Accuracy', 'C INDEX']

# %%
df[columns_to_num] = df[columns_to_num].astype(float)

# %%
df[columns_metrics] = df[columns_metrics] / 100

# %%
df_mean = df.groupby('Primary study Bibtex ID').mean()
df_mean.head()
# Out:
#                          Total CTs  C-19 CTs  ...  Balanced Accuracy  C INDEX
# Primary study Bibtex ID                       ...
# abbas2020classification        0.0       0.0  ...                NaN     94.0
# acar2020improving           3132.0    1331.0  ...                NaN      NaN
# al2020fast                     0.0       0.0  ...                NaN      NaN
# alom2020covid_mtnet            NaN       NaN  ...                NaN      NaN
# alqudah2019covid               0.0       0.0  ...                NaN      NaN
#
# [5 rows x 18 columns]

# %%
df_mean['Date'] = df[['Primary study Bibtex ID','Date']].groupby('Primary study Bibtex ID').min()
df_mean.head()
# Out:
#                          Total CTs  C-19 CTs  ...  C INDEX       Date
# Primary study Bibtex ID                       ...
# abbas2020classification        0.0       0.0  ...     94.0 2020-03-26
# acar2020improving           3132.0    1331.0  ...      NaN 2020-06-14
# al2020fast                     0.0       0.0  ...      NaN 2020-06-19
# alom2020covid_mtnet            NaN       NaN  ...      NaN 2020-04-07
# alqudah2019covid               0.0       0.0  ...      NaN 2020-03-01
#
# [5 rows x 19 columns]

# %% [markdown]
# ## describe the data

# %%
df.groupby('Primary study Bibtex ID').describe()
# Out:
#                         Total CTs                       ... C INDEX
#                             count    mean  std     min  ...     25%   50%   75%   max
# Primary study Bibtex ID                                 ...
# abbas2020classification       4.0     0.0  0.0     0.0  ...    94.0  94.0  94.0  94.0
# acar2020improving             1.0  3132.0  NaN  3132.0  ...     NaN   NaN   NaN   NaN
# al2020fast                    1.0     0.0  NaN     0.0  ...     NaN   NaN   NaN   NaN
# alom2020covid_mtnet           0.0     NaN  NaN     NaN  ...     NaN   NaN   NaN   NaN
# alqudah2019covid              1.0     0.0  NaN     0.0  ...     NaN   NaN   NaN   NaN
# ...                           ...     ...  ...     ...  ...     ...   ...   ...   ...
# zhong2020using                1.0     0.0  NaN     0.0  ...     NaN   NaN   NaN   NaN
# zhou2020automatic             1.0   473.0  NaN   473.0  ...     NaN   NaN   NaN   NaN
# ...

# %%
df.groupby('Primary study Bibtex ID').describe().describe()
# Out:
#         Total CTs                 ...    C INDEX
#             count           mean  ...        75%        max
# count  138.000000     108.000000  ...  19.000000  19.000000
# mean     1.471014    3570.298765  ...  94.452632  94.452632
# std      1.630870   16877.362188  ...   4.349121   4.349121
# min      0.000000       0.000000  ...  81.000000  81.000000
# 25%      1.000000       0.000000  ...  93.000000  93.000000
# 50%      1.000000       0.000000  ...  95.000000  95.000000
# 75%      2.000000     747.000000  ...  97.500000  97.500000
# max     11.000000  132583.000000  ...  99.600000  99.600000
#
# [8 rows x 144 columns]

# %% [markdown]
# ## visualisation - preparation

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

from matplotlib.colors import LogNorm, SymLogNorm, TwoSlopeNorm, NoNorm, PowerNorm, Normalize

# %%
df_mean.head(10)
# Out:
#                               Total CTs  C-19 CTs  ...  C INDEX       Date
# Primary study Bibtex ID                            ...
# abbas2020classification             0.0       0.0  ...     94.0 2020-03-26
# acar2020improving                3132.0    1331.0  ...      NaN 2020-06-14
# al2020fast                          0.0       0.0  ...      NaN 2020-06-19
# alom2020covid_mtnet                 NaN       NaN  ...      NaN 2020-04-07
# alqudah2019covid                    0.0       0.0  ...      NaN 2020-03-01
# amyar2020multi                   1044.0     449.0  ...      NaN 2020-04-21
# angelov2020explainable              NaN       NaN  ...     89.0 2020-04-29
# apostolopoulos2020extracting        0.0       0.0  ...      NaN 2020-04-01
# ardakani2020application          1020.0     510.0  ...      NaN 2020-04-30
# asnaoui2020automated                0.0       0.0  ...      NaN 2020-03-31
#
# [10 rows x 19 columns]

# %%
df_mean.describe()
# Out:
#            Total CTs      C-19 CTs  ...  Balanced Accuracy    C INDEX
# count     108.000000    106.000000  ...                1.0  19.000000
# mean     3570.298765   1379.445597  ...               66.0  94.452632
# std     16877.362188   7370.318711  ...                NaN   4.349121
# min         0.000000      0.000000  ...               66.0  81.000000
# 25%         0.000000      0.000000  ...               66.0  93.000000
# 50%         0.000000      0.000000  ...               66.0  95.000000
# 75%       747.000000    349.750000  ...               66.0  97.500000
# max    132583.000000  65806.000000  ...               66.0  99.600000
#
# [8 rows x 18 columns]

# %%
df_mean = df_mean.sort_values('Date')

# %%
# df_mean['Date'] = df_mean['Date'].astype('string').str[5:]

# %%
def plot_chart(df, pos_first, pos_second, metric_name, total_name, c19_name, fill_total, fill_c19, color, include_empty=False):

  if include_empty:
    df = df[(~df[metric_name].isna()) & (df[total_name] != 0) & (df[c19_name] != 0)]
  else:
    df = df[(~df[metric_name].isna()) & (df[total_name] != 0) & (df[c19_name] != 0) &  (~df[total_name].isna()) & (~df[c19_name].isna())]

  # colors
  sns.scatterplot(ax=axes[pos_first, pos_second], x=df['Date'], y=df[metric_name], size=df[total_name].fillna(df[c19_name].median()), hue=df[c19_name].fillna(df[c19_name].median()), 
                palette=color, sizes=list(np.geomspace(20, 1500, len(df[total_name].fillna(df[c19_name].median()).unique()))), hue_norm=PowerNorm(gamma=0.2), legend=False)
  # # no colors
  # sns.scatterplot(ax=axes[pos_first, pos_second], x=df['Date'], y=df[metric_name], size=df[total_name].fillna(df[c19_name].median()),
  #                 sizes=list(np.geomspace(20, 1500, len(df[total_name].fillna(df[c19_name].median()).unique()))), hue_norm=PowerNorm(gamma=0.2), legend=False)
  
  axes[pos_first, pos_second].set_ylabel(metric_name + ' [%]', fontsize=20)
  for y in axes[pos_first, pos_second].get_yticklabels():
      y.set_fontsize(15)  

  axes[pos_first, pos_second].set_xlabel('Date', fontsize=20)
  axes[pos_first, pos_second].xaxis.set_visible(True)
  print()
  for x in axes[pos_first, pos_second].get_xticklabels():
      x.set_rotation(90)
      x.set_fontsize(15)

  step = 10 
  # step = int((len(axes[pos_first, pos_second].get_xticklabels()))/10) - 1
  if step < 1:
    step = 1

  loc = plticker.MultipleLocator(base=step) # this locator puts ticks at regular intervals
  axes[pos_first, pos_second].xaxis.set_major_locator(loc)

# %% [markdown]
# ### visualisation - hue

# %%
df_mean[['C-19 CTs', 'C-19 patients', 'C-19 X-rays']].head(20)
# Out:
#                              C-19 CTs  C-19 patients  C-19 X-rays
# Primary study Bibtex ID
# xu2020deep                 259.000000     151.333333     0.000000
# chen2020deep              6996.000000      53.200000     0.000000
# farid2020novel              51.000000            NaN     0.000000
# alqudah2019covid             0.000000            NaN    48.000000
# salman2020covid                   NaN            NaN          NaN
# islam2020distinguishing           NaN     108.000000          NaN
# gozes2020rapid              94.000000      72.666667     0.000000
# shan2020lung                      NaN     399.000000     0.000000
# zheng2020deep              436.000000     313.000000     0.000000
# hu2020automated                   NaN     469.000000     0.000000
# barstugan2020coronavirus    53.000000      53.000000     0.000000
# wang2020covid                0.000000     140.500000   112.333333
# shi2020large              1326.400000    1658.000000     0.000000
# ...

# %%
df_mean[df_mean['C-19 CTs'] != 0].describe()
# Out:
#            Total CTs      C-19 CTs  ...  Balanced Accuracy    C INDEX
# count      41.000000     39.000000  ...                0.0  14.000000
# mean     7646.555285   3749.262393  ...                NaN  95.257143
# std     24628.154330  11873.511259  ...                NaN   3.319341
# min        10.000000     10.000000  ...                NaN  89.000000
# 25%       495.000000    300.000000  ...                NaN  92.500000
# 50%       852.000000    436.000000  ...                NaN  95.000000
# 75%      2124.000000   1126.500000  ...                NaN  98.750000
# max    132583.000000  65806.000000  ...                NaN  99.600000
#
# [8 rows x 18 columns]

# %%
df_mean[['C-19 CTs', 'C-19 patients', 'C-19 X-rays']].describe()
# Out:
#            C-19 CTs  C-19 patients  C-19 X-rays
# count    106.000000      61.000000   116.000000
# mean    1379.445597     362.303123   148.658046
# std     7370.318711     539.062958   434.574324
# min        0.000000      33.000000     0.000000
# 25%        0.000000      99.000000     0.000000
# 50%        0.000000     151.000000     0.000000
# 75%      349.750000     383.333333   181.500000
# max    65806.000000    3389.000000  4273.000000

# %%
df_mean[['C-19 CTs', 'C-19 patients', 'C-19 X-rays']].hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f72527b97d0>,
# ...
#       dtype=object)

# %% [markdown]
# ## visualisation - charts

# %%
total_name = 'Total CTs'
c19_name = 'C-19 CTs'
include_empty = False

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total CTs'
c19_name = 'C-19 CTs'
include_empty = False

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 1000, 50, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 50, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 50, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 50, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 50, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 50, 'Greys', include_empty)

# %%
total_name = 'Total CTs'
c19_name = 'C-19 CTs'
include_empty = True

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 1000, 50, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 50, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 50, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 50, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 50, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 50, 'Greys', include_empty)

# %%
total_name = 'Total CTs'
c19_name = 'C-19 CTs'
include_empty = True

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 1000, 50, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 50, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 50, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 50, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 50, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 50, 'Greys', include_empty)

# %%
total_name = 'Total X-Rays'
c19_name = 'C-19 X-rays'
include_empty = False

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total X-Rays'
c19_name = 'C-19 X-rays'
include_empty = False

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total X-Rays'
c19_name = 'C-19 X-rays'
include_empty = True

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total X-Rays'
c19_name = 'C-19 X-rays'
include_empty = True

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total patients'
c19_name = 'C-19 patients'
include_empty = False

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total patients'
c19_name = 'C-19 patients'
include_empty = False

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total patients'
c19_name = 'C-19 patients'
include_empty = True

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)

# %%
total_name = 'Total patients'
c19_name = 'C-19 patients'
include_empty = True

fig, axes = plt.subplots(2, 3, figsize=(36, 20))
plot_chart(df_mean, 0, 0, 'Accuracy', total_name, c19_name, 0, 5, 'Blues', include_empty)
plot_chart(df_mean, 0, 1, 'AUC', total_name, c19_name, 0, 5, 'Greens', include_empty)
plot_chart(df_mean, 0, 2, 'F1', total_name, c19_name, 0, 5, 'Oranges', include_empty)
plot_chart(df_mean, 1, 0, 'Precision', total_name, c19_name, 0, 5, 'Reds', include_empty)
plot_chart(df_mean, 1, 1, 'Sensitivity', total_name, c19_name, 0, 5, 'Purples', include_empty)
plot_chart(df_mean, 1, 2, 'Specifity', total_name, c19_name, 0, 5, 'Greys', include_empty)
